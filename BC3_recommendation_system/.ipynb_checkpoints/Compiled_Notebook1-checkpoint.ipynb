# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# data
import pandas as pd
import numpy as np
from datetime import datetime
from math import ceil
import datetime as dt


# plots
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# processing
from collections import Counter

# MBA
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

#CF
# !pip install --upgrade implicit
import os; os.environ['OPENBLAS_NUM_THREADS']='1'
import implicit
from scipy.sparse import coo_matrix
from implicit.evaluation import mean_average_precision_at_k
#CF source information and code from: 
# http://yifanhu.net/PUB/cf.pdf?fbclid=IwAR1XXu-uOKea06KXjvhR6oDNKqs_X-gk70YltpL4gUrDc0kwGFXivGcRrEI
# https://www.kaggle.com/code/julian3833/h-m-implicit-als-model-0-014
# https://medium.com/radon-dev/als-implicit-collaborative-filtering-5ed653ba39fe
# https://implicit.readthedocs.io/en/latest/quickstart.html

sns.set()
# %matplotlib inline

# %%
#to be run depending on the need
pd.set_option('display.max_rows', None)

# %%
#to be run depending on the need
pd.set_option('display.max_rows', 20)

# %%
''' The notebook is organized into the following sections: 
- Exploration
- Preprocessing
- Customer Segmentation/RFM Analysis
- Cold Start - Item popularity 
- Market Basket Analysis
- Collaborative Filtering '''
# Out:
# ' The notebook is organized into the following sections: \n- Exploration\n- Preprocessing\n- Customer Segmentation/RFM Analysis\n- Cold Start - Item popularity \n- Market Basket Analysis\n- Collaborative Filtering '

# %% [markdown]
# ## Exploration

# %%
#read in the data
df = pd.read_csv('retail.csv')

# %%
df_backup=df.copy()

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.groupby(['StockCode', 'Description'])['Quantity'].count()
# Out:
# StockCode     Description
# 10002         INFLATABLE POLITICAL GLOBE             71
# 10080         GROOVY CACTUS INFLATABLE               22
#               check                                   1
# 10120         DOGGY RUBBER                           30
# 10123C        HEARTS WRAPPING TAPE                    3
#                                                      ..
# gift_0001_20  to push order througha s stock was      1
# gift_0001_30  Dotcomgiftshop Gift Voucher £30.00      7
# gift_0001_40  Dotcomgiftshop Gift Voucher £40.00      3
# gift_0001_50  Dotcomgiftshop Gift Voucher £50.00      4
# m             Manual                                  1
# Name: Quantity, Length: 4792, dtype: int64

# %%
#looking at the counts for some of the products
frequency = df.groupby('Description')['Quantity'].sum()
frequency = frequency.sort_values(ascending=False)
frequency[:30].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Description'>

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#lets look at the total profit of each item purchase
df['TotalValue'] = df['UnitPrice'] * df['Quantity']

# %%
#check for most profitable descriptions - we see some are very negative
profitable = df.groupby('Description')['TotalValue'].sum()
profitable = profitable.sort_values(ascending=False)
#profitable[:30].plot(kind='bar')

profitable
# Out:
# Description
# DOTCOM POSTAGE                        206245.480
# REGENCY CAKESTAND 3 TIER              164762.190
# WHITE HANGING HEART T-LIGHT HOLDER     99668.470
# PARTY BUNTING                          98302.980
# JUMBO BAG RED RETROSPOT                92356.030
#                                          ...
# Bank Charges                           -7175.639
# CRUK Commission                        -7933.430
# Adjust bad debt                       -11062.060
# Manual                                -68671.640
# AMAZON FEE                           -221520.500
# Name: TotalValue, Length: 4223, dtype: float64

# %% [markdown]
# ## Processing

# %%
#drop values where description is blank
df=df[df["Description"].isna()==False]

#we are only interested in relevent products, and some look non-relevent, so lets drop as many as we can
df['Description'] = df['Description'].str.lower()
df['StockCode'] = df['StockCode'].str.lower()

#this description is not a product in the traditional sense
df=df[df['Description'].str.contains('amazon')==False]

# only products with value
df=df[df['UnitPrice']!=0]

# %%
#now lets deal with the inconsistencies in the stock code and description
codes = df[['StockCode','Description']].drop_duplicates().groupby('StockCode').count()
duplicated_codes = codes.index[codes['Description']>1].to_numpy()

#Here is the list of inconsistent descriptions
df[['StockCode','Description',"UnitPrice"]].drop_duplicates()[df['StockCode'].isin(duplicated_codes)==True].sort_values("StockCode")
# Out:
#        StockCode                          Description  UnitPrice
# 47284     16156l                       wrap, carousel       0.42
# 138080    16156l                        wrap carousel       0.42
# 6467      17107d  flower fairy,5 summer b'draw liners       2.55
# 347764    17107d    flower fairy 5 summer draw liners       2.55
# 315743    17107d         flower fairy 5 drawer liners       2.55
# ...          ...                                  ...        ...
# 10792     90014b         gold m pearl  orbit necklace      10.62
# 89115     90014b         gold m pearl  orbit necklace      10.40
# 504721    90014c      silver and black orbit necklace       2.95
# 501725    90014c      silver and black orbit necklace      10.40
# 142063    90014c          silver/black orbit necklace       9.95
#
# [1304 rows x 3 columns]

# %%
#lets merge two tables, first table will be unique stock codes
df.groupby(["StockCode","Description"]).count().sort_values("StockCode")
# Out:
#                                                  InvoiceNo  Quantity  \
# StockCode    Description
# 10002        inflatable political globe                 71        71
# 10080        groovy cactus inflatable                   22        22
# 10120        doggy rubber                               30        30
# 10123c       hearts wrapping tape                        3         3
# 10124a       spots on red bookcover tape                 5         5
# ...                                                    ...       ...
# gift_0001_50 dotcomgiftshop gift voucher £50.00          4         4
# m            manual                                    566       566
# pads         pads to match all cushions                  3         3
# post         postage                                  1252      1252
# s            samples                                    63        63
#
#                                                  InvoiceDate  UnitPrice  \
# StockCode    Description
# 10002        inflatable political globe                   71         71
# 10080        groovy cactus inflatable                     22         22
# 10120        doggy rubber                                 30         30
# 10123c       hearts wrapping tape                          3          3
# 10124a       spots on red bookcover tape                   5          5
# ...                                                      ...        ...
# gift_0001_50 dotcomgiftshop gift voucher £50.00            4          4
# m            manual                                      566        566
# pads         pads to match all cushions                    3          3
# post         postage                                    1252       1252
# s            samples                                      63         63
#
#                                                  CustomerID  Country  \
# StockCode    Description
# 10002        inflatable political globe                  49       71
# 10080        groovy cactus inflatable                    21       22
# 10120        doggy rubber                                30       30
# 10123c       hearts wrapping tape                         3        3
# 10124a       spots on red bookcover tape                  5        5
# ...                                                     ...      ...
# gift_0001_50 dotcomgiftshop gift voucher £50.00           0        4
# m            manual                                     459      566
# pads         pads to match all cushions                   3        3
# post         postage                                   1196     1252
# s            samples                                      0       63
#
#                                                  TotalValue
# StockCode    Description
# 10002        inflatable political globe                  71
# 10080        groovy cactus inflatable                    22
# 10120        doggy rubber                                30
# 10123c       hearts wrapping tape                         3
# 10124a       spots on red bookcover tape                  5
# ...                                                     ...
# gift_0001_50 dotcomgiftshop gift voucher £50.00           4
# m            manual                                     566
# pads         pads to match all cushions                   3
# post         postage                                   1252
# s            samples                                     63
#
# [4061 rows x 7 columns]

# %%
#finding the most common description for each stock code
desc_modes=df[["StockCode","Description"]].groupby(["StockCode"]).apply(pd.DataFrame.mode).reset_index(drop=True)

# %%
#sanity check - look at one that we know has multiple descriptions 
desc_modes[desc_modes["StockCode"]=="16156l"]
# Out:
#    StockCode    Description
# 42    16156l  wrap carousel

# %%
desc_modes.shape
# Out:
# (3830, 2)

# %%
#merging our new descriptions
df_merge = pd.merge(df, desc_modes, on ='StockCode', how ="left")
df=df_merge.drop('Description_x', axis=1).rename(columns = {'Description_y':'Description'})

# %%
#now dropping any products that are not products 
desc_to_drop = ["postage",'discount','manual','samples']
codes_do_drop = ['dot','m','d','s','b',"bank charges","cruk",'pads','c2']

df=df[df["StockCode"].isin(codes_do_drop)==False]
df=df[df["Description"].isin(desc_to_drop)==False]

# %%
#fixing the Country column
df.replace({"EIRE":"Ireland"}, inplace=True)

# %%
#now lets drop products that do not have enough value
#looking at the total sum value of each product, lets drop the products that did not reach a certain threshold
df[["StockCode","Description","TotalValue"]].groupby('StockCode')['TotalValue'].sum().hist(bins=200)
# Out:
# <AxesSubplot:>

# %%
prodvalue=df[["StockCode","Description","TotalValue"]].groupby('StockCode')['TotalValue'].sum().sort_values().to_frame()
tv = prodvalue["TotalValue"].sum()

# %%
#lets make our arbitrary cutoff 300 over a 2 year period
prodvalue = prodvalue[prodvalue["TotalValue"]>=300]

# %%
ntv = prodvalue["TotalValue"].sum()

#by removing the products below the set threshold, we have removed only a small proportion of revenue (less than 2%)
(tv-ntv)/tv
# Out:
# 0.012417380900741178

# %%
#but have reduced our item list by a lot, could be readjusted based on the scarcity of our matrix
prodvalue.shape
# Out:
# (2489, 1)

# %%
high_prof_codes = prodvalue.index.to_numpy()

#reduced dataframe
df=df[df['StockCode'].isin(high_prof_codes)==True]

# %%
#checkpoint 2
df_backup2=df.copy()

# %%
#expose to csv so we do not have to run the preprocessing each time
df.to_csv('cleaned_data2.csv', index=False)

# %% [markdown]
# ## reshaping into new dataframes

# %%
df = pd.read_csv('cleaned_data2.csv')

# %%
df.head()
# Out:
#   InvoiceNo StockCode  Quantity     InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123a         6  12/1/2010 8:26       2.55     17850.0
# 1    536365     71053         6  12/1/2010 8:26       3.39     17850.0
# 2    536365    84406b         8  12/1/2010 8:26       2.75     17850.0
# 3    536365    84029g         6  12/1/2010 8:26       3.39     17850.0
# 4    536365    84029e         6  12/1/2010 8:26       3.39     17850.0
#
#           Country  TotalValue                          Description
# 0  United Kingdom       15.30   white hanging heart t-light holder
# 1  United Kingdom       20.34                  white metal lantern
# 2  United Kingdom       22.00       cream cupid hearts coat hanger
# 3  United Kingdom       20.34  knitted union flag hot water bottle
# 4  United Kingdom       20.34       red woolly hottie white heart.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516528 entries, 0 to 516527
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    516528 non-null  object
#  1   StockCode    516528 non-null  object
#  2   Quantity     516528 non-null  int64
#  3   InvoiceDate  516528 non-null  object
#  4   UnitPrice    516528 non-null  float64
#  5   CustomerID   392980 non-null  float64
#  6   Country      516528 non-null  object
#  7   TotalValue   516528 non-null  float64
#  8   Description  516528 non-null  object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 35.5+ MB

# %%
# customer dataframe - remove rows without customer id 
df_cust = df.dropna()
df_cust.shape
# Out:
# (392980, 9)

# %%
#beginning of customers table - first row is a return 
customers = pd.DataFrame([df_cust.groupby("CustomerID")["InvoiceNo"].nunique().rename("Purchases"),
                          df_cust.groupby("CustomerID")['StockCode'].nunique().rename("unique_products"),
                          df_cust.groupby("CustomerID")['Quantity'].sum().rename("total_no_items"),
                          df_cust.groupby("CustomerID")['TotalValue'].sum().rename("monetary"),
                          df_cust.groupby("CustomerID")['TotalValue'].median().rename("med_purchase_value")
                          
                         ]).T
#Country
#recency of most recent purchase
#frequency 
#length of time as a customer
customers.head()
# Out:
#             Purchases  unique_products  total_no_items  monetary  \
# CustomerID
# 12346.0           2.0              1.0             0.0      0.00
# 12347.0           7.0            100.0          2392.0   4215.50
# 12348.0           4.0             19.0          2260.0   1376.04
# 12349.0           1.0             72.0           630.0   1457.55
# 12350.0           1.0             16.0           196.0    294.40
#
#             med_purchase_value
# CustomerID
# 12346.0                   0.00
# 12347.0                  17.00
# 12348.0                  41.76
# 12349.0                  17.70
# 12350.0                  18.75

# %%
#product table, sorted into two tables, one of purchases and one of returns 
df_purchases = df[df["Quantity"]>0]

df_returns = df[df["Quantity"]<0]

# %%
products = pd.DataFrame([df.groupby("StockCode")['Description'].unique().rename("Description"),
                         df.groupby("StockCode")['UnitPrice'].mean().rename("UnitPrice"), #problem with the unit price
                         df_purchases.groupby("StockCode")["InvoiceNo"].nunique().rename("times_purchased"),
                         df_returns.groupby("StockCode")['InvoiceNo'].nunique().rename("times_returned"),
                         df_purchases.groupby("StockCode")['Quantity'].mean().rename("avg_quant_purchased"),
                         df.groupby("StockCode")['TotalValue'].sum().rename("net_item_revenue")
                         ]).T
products.times_returned.fillna(0, inplace=True)
#should add the frequency over different times of the year etc. 
# 12 variables for times purchased in each month 
products
# Out:
#                               Description  UnitPrice times_purchased  \
# StockCode
# 10002       [inflatable political globe ]    1.08662              71
# 10125           [mini funky design tapes]   0.859681              91
# 10133      [colouring pencils brown tube]   0.649045             196
# 10135      [colouring pencils brown tube]   1.410167             175
# 11001       [asstd design racing car pen]   1.878167             113
# ...                                   ...        ...             ...
# 90200d         [pink sweetheart bracelet]   4.189114              78
# 90200e        [green sweetheart bracelet]   4.187727              44
# 90209b     [green enamel+glass hair comb]   2.074464              54
# 90209c      [pink enamel+glass hair comb]   2.060625              31
# c2                             [carriage]  49.636364             141
#
#            times_returned avg_quant_purchased net_item_revenue
# StockCode
# 10002                 0.0           12.112676           759.89
# 10125                 0.0           13.787234           994.84
# 10133                 1.0           14.479798          1540.02
# 10135                 1.0           12.463687          2206.14
# 11001                 5.0           14.043478          2152.39
# ...                   ...                 ...              ...
# 90200d                0.0            2.227848           729.57
# 90200e                0.0            2.340909           423.41
# 90209b                0.0            3.303571           357.74
# 90209c                1.0            8.483871            474.2
# c2                    2.0            1.007092           6986.0
#
# [2489 rows x 6 columns]

# %%
# now we can move forward with the cold start problem (+ customer segmentation/RFM)

# collaborative filtering 

# MBA/complimentary/apriori

# %% [markdown]
# ## RFM Analysis

# %%
df.head()
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123a         6   12/1/2010 8:26       2.55     17850.0
# 1         536365     71053         6   12/1/2010 8:26       3.39     17850.0
# 2         536365    84406b         8   12/1/2010 8:26       2.75     17850.0
# 3         536365    84029g         6   12/1/2010 8:26       3.39     17850.0
# 4         536365    84029e         6   12/1/2010 8:26       3.39     17850.0
# ...          ...       ...       ...              ...        ...         ...
# 516523    581587     22613        12  12/9/2011 12:50       0.85     12680.0
# 516524    581587     22899         6  12/9/2011 12:50       2.10     12680.0
# 516525    581587     23254         4  12/9/2011 12:50       4.15     12680.0
# 516526    581587     23255         4  12/9/2011 12:50       4.15     12680.0
# 516527    581587     22138         3  12/9/2011 12:50       4.95     12680.0
#
#                Country  TotalValue                          Description
# 0       United Kingdom       15.30   white hanging heart t-light holder
# 1       United Kingdom       20.34                  white metal lantern
# 2       United Kingdom       22.00       cream cupid hearts coat hanger
# 3       United Kingdom       20.34  knitted union flag hot water bottle
# 4       United Kingdom       20.34       red woolly hottie white heart.
# ...                ...         ...                                  ...
# 516523          France       10.20          pack of 20 spaceboy napkins
# 516524          France       12.60         children's apron dolly girl
# 516525          France       16.60        childrens cutlery dolly girl
# 516526          France       16.60      childrens cutlery circus parade
# 516527          France       14.85        baking set 9 piece retrospot
#
# [516528 rows x 9 columns]

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format = '%m/%d/%Y %H:%M')

# %%
today_date=dt.datetime(2011, 12, 11)

rfm=df.groupby("CustomerID").agg({"InvoiceDate": lambda InvoiceDate : (today_date-InvoiceDate.max()).days,
                                   "InvoiceNo" : lambda Invoice : Invoice.nunique(),
                                  "TotalValue" : lambda TotalPrice : TotalPrice.sum()
                                   })

rfm.columns=["recency","frequency","monetary"]

rfm=rfm[rfm["monetary"] > 0]
rfm
# Out:
#             recency  frequency  monetary
# CustomerID
# 12347.0           3          7   4215.50
# 12348.0          76          4   1376.04
# 12349.0          19          1   1457.55
# 12350.0         311          1    294.40
# 12352.0          37          8   1265.41
# ...             ...        ...       ...
# 18280.0         278          1    180.60
# 18281.0         181          1     80.82
# 18282.0           8          3    176.60
# 18283.0           4         16   2073.43
# 18287.0          43          3   1798.22
#
# [4319 rows x 3 columns]

# %%
#generate RFM scores

rfm["recency_score"]=pd.qcut(rfm["recency"],5,labels=[5,4,3,2,1])

rfm["frequency_score"]= pd.qcut(rfm["frequency"].rank(method="first"),5, labels=[1,2,3,4,5])

rfm["monetary_score"]=pd.qcut(rfm["monetary"],5,labels=[1,2,3,4,5])

rfm["RFM_score"]=(rfm["recency_score"].astype(str)+rfm["frequency_score"].astype(str)+rfm["monetary_score"].astype(str))

rfm[["recency_score", "frequency_score", "monetary_score", 'RFM_score']] = rfm[["recency_score", "frequency_score", "monetary_score", "RFM_score"]].astype(int)


rfm
# Out:
#             recency  frequency  monetary  recency_score  frequency_score  \
# CustomerID
# 12347.0           3          7   4215.50              5                4
# 12348.0          76          4   1376.04              2                4
# 12349.0          19          1   1457.55              4                1
# 12350.0         311          1    294.40              1                1
# 12352.0          37          8   1265.41              3                5
# ...             ...        ...       ...            ...              ...
# 18280.0         278          1    180.60              1                2
# 18281.0         181          1     80.82              1                2
# 18282.0           8          3    176.60              5                4
# 18283.0           4         16   2073.43              5                5
# 18287.0          43          3   1798.22              3                4
#
#             monetary_score  RFM_score
# CustomerID
# 12347.0                  5        545
# 12348.0                  4        244
# 12349.0                  4        414
# 12350.0                  2        112
# 12352.0                  4        354
# ...                    ...        ...
# 18280.0                  1        121
# 18281.0                  1        121
# 18282.0                  1        541
# 18283.0                  5        555
# 18287.0                  4        344
#
# [4319 rows x 7 columns]

# %% [markdown]
# ### Segmenting the customers based on the RFM score:

# %%
Champions=[555, 554, 544, 545, 454, 455, 445]
Loyal=[543, 444, 435, 355, 354, 345, 344, 335]
Potential_Loyalist=[553, 551, 552, 541, 542, 533, 532, 531, 452, 451, 442, 441, 431, 453, 433, 432, 423, 353,
                    352, 351, 342, 341, 333, 323, 525, 524, 523, 522, 521, 515, 514, 513, 425,424, 413,414,
                    415, 315, 314, 313]
New_Customers=[512, 511, 422, 421, 412, 411, 311]
Need_Attention=[535, 534, 443, 434, 343, 334, 325, 324]
About_To_Sleep=[331, 321, 312, 221, 213, 231, 241, 251]
At_Risk=[255, 254, 245, 244, 253, 252, 243, 242, 235, 234, 225, 224, 153, 152, 145, 143, 142, 135, 134, 133, 125, 124]
Cannot_Lose_Them=[155, 154, 144, 214,215,115, 114, 113]
Hibernating=[332, 322, 233, 232, 223, 222, 132, 123, 122, 212, 211]
Lost_customers=[111, 112, 121, 131,141,151]

# %%
rfm['label']=""
for i in range(len(rfm)):
    if rfm.iloc[i][6] in Champions: 
        rfm.iloc[i, 7]='Champions'
    elif rfm.iloc[i][6] in Loyal: 
        rfm.iloc[i, 7]='Loyal'
    elif rfm.iloc[i][6] in Potential_Loyalist: 
        rfm.iloc[i, 7]='Potential_Loyalist'
    elif rfm.iloc[i][6] in New_Customers: 
        rfm.iloc[i, 7]='New_Customers'
    elif rfm.iloc[i][6] in Need_Attention: 
        rfm.iloc[i, 7]='Need_Attention'
    elif rfm.iloc[i][6] in About_To_Sleep: 
        rfm.iloc[i, 7]='About_To_Sleep'
    elif rfm.iloc[i][6] in At_Risk: 
        rfm.iloc[i, 7]='At_Risk'
    elif rfm.iloc[i][6] in Cannot_Lose_Them: 
        rfm.iloc[i, 7]='Cannot_Lose_Them'
    elif rfm.iloc[i][6] in Hibernating: 
        rfm.iloc[i, 7]='Hibernating'
    else:
        rfm.iloc[i, 7]='Lost_customers'

# %%
rfm
# Out:
#             recency  frequency  monetary  recency_score  frequency_score  \
# CustomerID
# 12347.0           3          7   4215.50              5                4
# 12348.0          76          4   1376.04              2                4
# 12349.0          19          1   1457.55              4                1
# 12350.0         311          1    294.40              1                1
# 12352.0          37          8   1265.41              3                5
# ...             ...        ...       ...            ...              ...
# 18280.0         278          1    180.60              1                2
# 18281.0         181          1     80.82              1                2
# 18282.0           8          3    176.60              5                4
# 18283.0           4         16   2073.43              5                5
# 18287.0          43          3   1798.22              3                4
#
#             monetary_score  RFM_score               label
# CustomerID
# 12347.0                  5        545           Champions
# 12348.0                  4        244             At_Risk
# 12349.0                  4        414  Potential_Loyalist
# 12350.0                  2        112      Lost_customers
# 12352.0                  4        354               Loyal
# ...                    ...        ...                 ...
# 18280.0                  1        121      Lost_customers
# 18281.0                  1        121      Lost_customers
# 18282.0                  1        541  Potential_Loyalist
# 18283.0                  5        555           Champions
# 18287.0                  4        344               Loyal
#
# [4319 rows x 8 columns]

# %%
clusters= rfm.groupby('label', as_index=False).agg({'recency':'mean' , 'frequency':'mean', 'monetary':'mean',
                                          'recency_score':'count'
    
})
clusters.rename(columns={'recency_score': 'Count'}, inplace=True)

# %%
clusters
# Out:
#                 label     recency  frequency     monetary  Count
# 0      About_To_Sleep   85.273063   1.457565   271.266273    271
# 1             At_Risk  141.430657   4.464720  1660.902457    411
# 2    Cannot_Lose_Them  226.436170   2.712766  1330.885106     94
# 3           Champions   11.128205  14.125874  6300.954522    858
# 4         Hibernating  149.431373   1.752101   386.324762    714
# 5      Lost_customers  275.190678   1.146186   183.271525    472
# 6               Loyal   36.442353   6.204706  2132.777388    425
# 7      Need_Attention   31.466403   3.553360  1075.259526    253
# 8       New_Customers   28.498168   1.131868   209.586886    273
# 9  Potential_Loyalist   25.691606   2.529197   590.350766    548

# %%
#now we can locate the RFM score of any customer
rfm.loc[rfm.index==12853]
# Out:
#             recency  frequency  monetary  recency_score  frequency_score  \
# CustomerID
# 12853.0         108          9    1881.7              2                5
#
#             monetary_score  RFM_score    label
# CustomerID
# 12853.0                  4        254  At_Risk

# %% [markdown]
# ## Cold Start Problem:

# %%
#next is the cold start
df['InvoiceMonth']=df.InvoiceDate.dt.month_name()

# %%
df.head()
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 0         536365    85123a         6 2010-12-01 08:26:00       2.55
# 1         536365     71053         6 2010-12-01 08:26:00       3.39
# 2         536365    84406b         8 2010-12-01 08:26:00       2.75
# 3         536365    84029g         6 2010-12-01 08:26:00       3.39
# 4         536365    84029e         6 2010-12-01 08:26:00       3.39
# ...          ...       ...       ...                 ...        ...
# 516523    581587     22613        12 2011-12-09 12:50:00       0.85
# 516524    581587     22899         6 2011-12-09 12:50:00       2.10
# 516525    581587     23254         4 2011-12-09 12:50:00       4.15
# 516526    581587     23255         4 2011-12-09 12:50:00       4.15
# 516527    581587     22138         3 2011-12-09 12:50:00       4.95
#
#         CustomerID         Country  TotalValue  \
# 0          17850.0  United Kingdom       15.30
# 1          17850.0  United Kingdom       20.34
# 2          17850.0  United Kingdom       22.00
# 3          17850.0  United Kingdom       20.34
# 4          17850.0  United Kingdom       20.34
# ...            ...             ...         ...
# 516523     12680.0          France       10.20
# 516524     12680.0          France       12.60
# 516525     12680.0          France       16.60
# 516526     12680.0          France       16.60
# 516527     12680.0          France       14.85
#
#                                 Description InvoiceMonth
# 0        white hanging heart t-light holder     December
# 1                       white metal lantern     December
# 2            cream cupid hearts coat hanger     December
# 3       knitted union flag hot water bottle     December
# 4            red woolly hottie white heart.     December
# ...                                     ...          ...
# 516523          pack of 20 spaceboy napkins     December
# 516524         children's apron dolly girl      December
# 516525        childrens cutlery dolly girl      December
# 516526      childrens cutlery circus parade     December
# 516527        baking set 9 piece retrospot      December
#
# [516528 rows x 10 columns]

# %%
products=df.groupby(['StockCode', 'Description'], as_index=False)['InvoiceNo'].nunique().sort_values(by= 'InvoiceNo', ascending=False).head(10)
products.rename(columns={'InvoiceNo': 'times_purchased'}, inplace=True)
plot = sns.barplot(x="times_purchased", y="Description", data=products, color="b")
plt.title('Top 10 products bought')
# Out:
# Text(0.5, 1.0, 'Top 10 products bought')

# %%
def top_products(month): 
    products=df.loc[df['InvoiceMonth']==month].groupby(['StockCode', 'Description'], as_index=False)['InvoiceNo'].nunique().sort_values(by= 'InvoiceNo', ascending=False).head(10) 
    products.rename(columns={'InvoiceNo': 'times_purchased'}, inplace=True)
    plot = sns.barplot(x="times_purchased", y="Description", data=products, color="b")
    plt.title('Top 10 products bought in '+ month)

# %%
for i in df['InvoiceMonth'].unique(): 
    top_products(i)
    plt.show()

# %% [markdown]
# ## Market Basket Analysis

# %%
df = pd.read_csv('cleaned_data2.csv')

df.drop('CustomerID', axis=1, inplace=True)

df
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  \
# 0         536365    85123a         6   12/1/2010 8:26       2.55
# 1         536365     71053         6   12/1/2010 8:26       3.39
# 2         536365    84406b         8   12/1/2010 8:26       2.75
# 3         536365    84029g         6   12/1/2010 8:26       3.39
# 4         536365    84029e         6   12/1/2010 8:26       3.39
# ...          ...       ...       ...              ...        ...
# 516523    581587     22613        12  12/9/2011 12:50       0.85
# 516524    581587     22899         6  12/9/2011 12:50       2.10
# 516525    581587     23254         4  12/9/2011 12:50       4.15
# 516526    581587     23255         4  12/9/2011 12:50       4.15
# 516527    581587     22138         3  12/9/2011 12:50       4.95
#
#                Country  TotalValue                          Description
# 0       United Kingdom       15.30   white hanging heart t-light holder
# 1       United Kingdom       20.34                  white metal lantern
# 2       United Kingdom       22.00       cream cupid hearts coat hanger
# 3       United Kingdom       20.34  knitted union flag hot water bottle
# 4       United Kingdom       20.34       red woolly hottie white heart.
# ...                ...         ...                                  ...
# 516523          France       10.20          pack of 20 spaceboy napkins
# 516524          France       12.60         children's apron dolly girl
# 516525          France       16.60        childrens cutlery dolly girl
# 516526          France       16.60      childrens cutlery circus parade
# 516527          France       14.85        baking set 9 piece retrospot
#
# [516528 rows x 8 columns]

# %%
#Removing null values for the invoice column and removing all the returns 
#(we are solely interested in the purchase behaviours)

df['InvoiceNo'] = df['InvoiceNo'].astype('str')
transaction_data = df[~df['Quantity'] < 0]

#Checking the top 4 countries to analyse the transactions per country
transaction_data
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  \
# 0         536365    85123a         6   12/1/2010 8:26       2.55
# 1         536365     71053         6   12/1/2010 8:26       3.39
# 2         536365    84406b         8   12/1/2010 8:26       2.75
# 3         536365    84029g         6   12/1/2010 8:26       3.39
# 4         536365    84029e         6   12/1/2010 8:26       3.39
# ...          ...       ...       ...              ...        ...
# 516523    581587     22613        12  12/9/2011 12:50       0.85
# 516524    581587     22899         6  12/9/2011 12:50       2.10
# 516525    581587     23254         4  12/9/2011 12:50       4.15
# 516526    581587     23255         4  12/9/2011 12:50       4.15
# 516527    581587     22138         3  12/9/2011 12:50       4.95
#
#                Country  TotalValue                          Description
# 0       United Kingdom       15.30   white hanging heart t-light holder
# 1       United Kingdom       20.34                  white metal lantern
# 2       United Kingdom       22.00       cream cupid hearts coat hanger
# 3       United Kingdom       20.34  knitted union flag hot water bottle
# 4       United Kingdom       20.34       red woolly hottie white heart.
# ...                ...         ...                                  ...
# 516523          France       10.20          pack of 20 spaceboy napkins
# 516524          France       12.60         children's apron dolly girl
# 516525          France       16.60        childrens cutlery dolly girl
# 516526          France       16.60      childrens cutlery circus parade
# 516527          France       14.85        baking set 9 piece retrospot
#
# [508118 rows x 8 columns]

# %%
# invoices from France
basket_fr = (transaction_data[transaction_data['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
 
# invoices from the United Kingdom
basket_uk = (transaction_data[transaction_data['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
 
# Invoices from Germany
basket_de = (transaction_data[transaction_data['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
 
# Invoices from Ireland
basket_ie = (transaction_data[transaction_data['Country'] =="Ireland"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
# Defining the encoding function to make 0 or 1 for the variables purchased

def encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1
 
# Encoding the datasets

basket_encoded = basket_fr.applymap(encode)
basket_fr = basket_encoded
 
basket_encoded = basket_uk.applymap(encode)
basket_uk = basket_encoded
 
basket_encoded = basket_de.applymap(encode)
basket_de = basket_encoded
 
basket_encoded = basket_ie.applymap(encode)
basket_ie = basket_encoded

# %%
#Running the apriori algorithm for French basket - Complementary products
frq_items = apriori(basket_fr, min_support = 0.05, use_colnames = True)
 
# Create a dataframe with the rules
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
#rules.head()
#rules.to_csv('france.csv', index=False)

rules[ (rules['lift'] >= 7) & (rules['confidence'] >= 0.8) ].head(20)
# Out:
#                                           antecedents  \
# 80  (set/6 red spotty paper cups, set/20 red retro...
# 9                       (childrens cutlery spaceboy )
# 38                     (pack of 6 skull paper plates)
# 8                     (childrens cutlery dolly girl )
# 68  (alarm clock bakelike green, alarm clock bakel...
# 70  (alarm clock bakelike pink, alarm clock bakeli...
# 3                         (alarm clock bakelike red )
# 2                        (alarm clock bakelike green)
# 69  (alarm clock bakelike green, alarm clock bakel...
# 39                       (pack of 6 skull paper cups)
#
#                         consequents  antecedent support  consequent support  \
# 80  (set/6 red spotty paper plates)            0.104987            0.131234
# 9   (childrens cutlery dolly girl )            0.070866            0.073491
# 38     (pack of 6 skull paper cups)            0.057743            0.065617
# 8     (childrens cutlery spaceboy )            0.073491            0.070866
# 68      (alarm clock bakelike red )            0.076115            0.097113
# 70     (alarm clock bakelike green)            0.076115            0.099738
# 3      (alarm clock bakelike green)            0.097113            0.099738
# 2       (alarm clock bakelike red )            0.099738            0.097113
# 69      (alarm clock bakelike pink)            0.081365            0.104987
# 39   (pack of 6 skull paper plates)            0.065617            0.057743
#
#      support  confidence       lift  leverage  conviction
# 80  0.102362    0.975000   7.429500  0.088584   34.750656
# 9   0.065617    0.925926  12.599206  0.060409   12.507874
# 38  0.052493    0.909091  13.854545  0.048705   10.278215
# 8   0.065617    0.892857  12.599206  0.060409    8.671916
# 68  0.065617    0.862069   8.876980  0.058225    6.545932
# 70  0.065617    0.862069   8.643376  0.058025    6.526903
# 3   0.081365    0.837838   8.400427  0.071679    5.551619
# 2   0.081365    0.815789   8.400427  0.071679    4.901387
# 69  0.065617    0.806452   7.681452  0.057075    4.624234
# 39  0.052493    0.800000  13.854545  0.048705    4.711286

# %%
#Substitute items French Basket
substitutes = association_rules(frq_items, metric="lift", min_threshold=0.0)
substitutes.sort_values(by='lift', ascending=True, inplace=True)
substitutes.head(10)
# Out:
#                               antecedents  \
# 57        (red toadstool led night light)
# 56                   (rabbit night light)
# 48       (plasters in tin circus parade )
# 49        (red toadstool led night light)
# 55        (red toadstool led night light)
# 54     (plasters in tin woodland animals)
# 51  (round snack boxes set of4 woodland )
# 50       (plasters in tin circus parade )
# 47       (plasters in tin circus parade )
# 46             (red retrospot mini cases)
#
#                               consequents  antecedent support  \
# 57                   (rabbit night light)            0.186352
# 56        (red toadstool led night light)            0.194226
# 48        (red toadstool led night light)            0.173228
# 49       (plasters in tin circus parade )            0.186352
# 55     (plasters in tin woodland animals)            0.186352
# 54        (red toadstool led night light)            0.175853
# 51       (plasters in tin circus parade )            0.162730
# 50  (round snack boxes set of4 woodland )            0.173228
# 47             (red retrospot mini cases)            0.173228
# 46       (plasters in tin circus parade )            0.141732
#
#     consequent support   support  confidence      lift  leverage  conviction
# 57            0.194226  0.055118    0.295775  1.522840  0.018924    1.144199
# 56            0.186352  0.055118    0.283784  1.522840  0.018924    1.136037
# 48            0.186352  0.052493    0.303030  1.626120  0.020212    1.167408
# 49            0.173228  0.052493    0.281690  1.626120  0.020212    1.150996
# 55            0.175853  0.055118    0.295775  1.681942  0.022348    1.170289
# 54            0.186352  0.055118    0.313433  1.681942  0.022348    1.185096
# 51            0.173228  0.055118    0.338710  1.955279  0.026929    1.250240
# 50            0.162730  0.055118    0.318182  1.955279  0.026929    1.227997
# 47            0.141732  0.052493    0.303030  2.138047  0.027941    1.231428
# 46            0.173228  0.052493    0.370370  2.138047  0.027941    1.313108

# %%
#Do the same for the UK

frq_items = apriori(basket_uk, min_support = 0.02, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
#rules.head()
#rules.to_csv('uk.csv', index=False)
rules[ (rules['lift'] >= 5) & (rules['confidence'] >= 0.8) ]
# Out:
#                                            antecedents  \
# 216  (pink regency teacup and saucer, roses regency...
# 217  (pink regency teacup and saucer, green regency...
# 26                    (pink regency teacup and saucer)
# 230  (jumbo bag pink polkadot, jumbo shopper vintag...
# 236  (jumbo storage bag suki, jumbo bag pink polkadot)
#
#                             consequents  antecedent support  \
# 216   (green regency teacup and saucer)            0.030556
# 217  (roses regency teacup and saucer )            0.032294
# 26    (green regency teacup and saucer)            0.039359
# 230           (jumbo bag red retrospot)            0.025454
# 236           (jumbo bag red retrospot)            0.028314
#
#      consequent support   support  confidence       lift  leverage  conviction
# 216            0.052254  0.027585    0.902752  17.276277  0.025988    9.745691
# 217            0.053599  0.027585    0.854167  15.936105  0.025854    6.489604
# 26             0.052254  0.032294    0.820513  15.702432  0.030238    5.280300
# 230            0.108488  0.020520    0.806167   7.430905  0.017759    4.599389
# 236            0.108488  0.022707    0.801980   7.392309  0.019635    4.502133

# %%
#Substitute items UK Basket
substitutes = association_rules(frq_items, metric="lift", min_threshold=0.0)
substitutes.sort_values(by='lift', ascending=True, inplace=True)
substitutes.head(10)
# Out:
#                               antecedents  \
# 110             (jumbo bag red retrospot)
# 111  (white hanging heart t-light holder)
# 193  (white hanging heart t-light holder)
# 192                       (party bunting)
# 188            (regency cakestand 3 tier)
# 189                       (party bunting)
# 34   (white hanging heart t-light holder)
# 35                (heart of wicker small)
# 105                      (popcorn holder)
# 104             (jumbo bag red retrospot)
#
#                               consequents  antecedent support  \
# 110  (white hanging heart t-light holder)            0.108488
# 111             (jumbo bag red retrospot)            0.121720
# 193                       (party bunting)            0.121720
# 192  (white hanging heart t-light holder)            0.089314
# 188                       (party bunting)            0.094472
# 189            (regency cakestand 3 tier)            0.089314
# 34                (heart of wicker small)            0.121720
# 35   (white hanging heart t-light holder)            0.065261
# 105             (jumbo bag red retrospot)            0.072662
# 104                      (popcorn holder)            0.108488
#
#      consequent support   support  confidence      lift  leverage  conviction
# 110            0.121720  0.024557    0.226357  1.859648  0.011352    1.135252
# 111            0.108488  0.024557    0.201750  1.859648  0.011352    1.116833
# 193            0.089314  0.021249    0.174574  1.954614  0.010378    1.103292
# 192            0.121720  0.021249    0.237916  1.954614  0.010378    1.152471
# 188            0.089314  0.020408    0.216024  2.418706  0.011971    1.161625
# 189            0.094472  0.020408    0.228500  2.418706  0.011971    1.173724
# 34             0.065261  0.021193    0.174113  2.667942  0.013249    1.131800
# 35             0.121720  0.021193    0.324742  2.667942  0.013249    1.300659
# 105            0.108488  0.021754    0.299383  2.759581  0.013871    1.272466
# 104            0.072662  0.021754    0.200517  2.759581  0.013871    1.159922

# %%
#Do the same for Germany

frq_items = apriori(basket_de, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
#rules.head()
#rules.to_csv('germany.csv', index=False)
rules[ (rules['lift'] >= 1.5) & (rules['confidence'] >= 0.6) ]
# Out:
#                              antecedents  \
# 10         (red retrospot charlotte bag)
# 12  (round snack boxes set of 4 fruits )
# 14                 (spaceboy lunch box )
#
#                               consequents  antecedent support  \
# 10               (woodland charlotte bag)            0.072398
# 12  (round snack boxes set of4 woodland )            0.162896
# 14  (round snack boxes set of4 woodland )            0.106335
#
#     consequent support   support  confidence      lift  leverage  conviction
# 10            0.131222  0.061086    0.843750  6.429957  0.051586    5.560181
# 12            0.253394  0.135747    0.833333  3.288690  0.094470    4.479638
# 14            0.253394  0.072398    0.680851  2.686930  0.045454    2.339367

# %%
#Substitute items German Basket
substitutes = association_rules(frq_items, metric="lift", min_threshold=0.0)
substitutes.sort_values(by='lift', ascending=True, inplace=True)
substitutes.head(10)
# Out:
#                               antecedents  \
# 5   (round snack boxes set of4 woodland )
# 4        (plasters in tin circus parade )
# 17  (round snack boxes set of4 woodland )
# 16               (woodland charlotte bag)
# 9   (round snack boxes set of4 woodland )
# 8      (plasters in tin woodland animals)
# 2    (round snack boxes set of 4 fruits )
# 3        (plasters in tin circus parade )
# 15  (round snack boxes set of4 woodland )
# 14                  (spaceboy lunch box )
#
#                               consequents  antecedent support  \
# 5        (plasters in tin circus parade )            0.253394
# 4   (round snack boxes set of4 woodland )            0.119910
# 17               (woodland charlotte bag)            0.253394
# 16  (round snack boxes set of4 woodland )            0.131222
# 9      (plasters in tin woodland animals)            0.253394
# 8   (round snack boxes set of4 woodland )            0.142534
# 2        (plasters in tin circus parade )            0.162896
# 3    (round snack boxes set of 4 fruits )            0.119910
# 15                  (spaceboy lunch box )            0.253394
# 14  (round snack boxes set of4 woodland )            0.106335
#
#     consequent support   support  confidence      lift  leverage  conviction
# 5             0.119910  0.058824    0.232143  1.935984  0.028439    1.146164
# 4             0.253394  0.058824    0.490566  1.935984  0.028439    1.465561
# 17            0.131222  0.065611    0.258929  1.973214  0.032360    1.172327
# 16            0.253394  0.065611    0.500000  1.973214  0.032360    1.493213
# 9             0.142534  0.076923    0.303571  2.129819  0.040806    1.231233
# 8             0.253394  0.076923    0.539683  2.129819  0.040806    1.621938
# 2             0.119910  0.052036    0.319444  2.664046  0.032503    1.293194
# 3             0.162896  0.052036    0.433962  2.664046  0.032503    1.478884
# 15            0.106335  0.072398    0.285714  2.686930  0.045454    1.251131
# 14            0.253394  0.072398    0.680851  2.686930  0.045454    2.339367

# %%
#Do the same for Ireland

frq_items = apriori(basket_ie, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
#rules.head()
#rules.to_csv('ireland.csv', index=False)
rules[ (rules['lift'] >= 10) & (rules['confidence'] >= 0.8) ]
# Out:
#                                            antecedents  \
# 194  (regency cakestand 3 tier, regency tea plate p...
# 181  (regency cakestand 3 tier, regency teapot roses )
# 67                             (regency teapot roses )
# 230  (regency tea plate roses , regency tea plate p...
# 223  (roses regency teacup and saucer , regency tea...
# 71                            (regency tea plate pink)
# 216  (roses regency teacup and saucer , regency mil...
# 168  (regency cakestand 3 tier, regency milk jug pi...
# 300  (regency tea plate green , roses regency teacu...
# 299  (roses regency teacup and saucer , regency cak...
# 286  (regency tea plate green , roses regency teacu...
# 200  (regency cakestand 3 tier, regency tea plate r...
# 227                            (regency teapot roses )
#
#                                            consequents  antecedent support  \
# 194                         (regency tea plate green )            0.056338
# 181                         (regency sugar bowl green)            0.052817
# 67                          (regency sugar bowl green)            0.066901
# 230                         (regency tea plate green )            0.059859
# 223                         (regency sugar bowl green)            0.059859
# 71                          (regency tea plate green )            0.070423
# 216                         (regency sugar bowl green)            0.066901
# 168                         (regency sugar bowl green)            0.063380
# 300  (regency cakestand 3 tier, regency tea plate r...            0.059859
# 299                         (regency tea plate green )            0.059859
# 286  (regency cakestand 3 tier, green regency teacu...            0.059859
# 200                         (regency tea plate green )            0.070423
# 227  (roses regency teacup and saucer , regency sug...            0.066901
#
#      consequent support   support  confidence       lift  leverage  conviction
# 194            0.080986  0.056338    1.000000  12.347826  0.051775         inf
# 181            0.088028  0.052817    1.000000  11.360000  0.048168         inf
# 67             0.088028  0.063380    0.947368  10.762105  0.057491   17.327465
# 230            0.080986  0.056338    0.941176  11.621483  0.051490   15.623239
# 223            0.088028  0.056338    0.941176  10.691765  0.051069   15.503521
# 71             0.080986  0.063380    0.900000  11.113043  0.057677    9.190141
# 216            0.088028  0.059859    0.894737  10.164211  0.053970    8.663732
# 168            0.088028  0.056338    0.888889  10.097778  0.050759    8.207746
# 300            0.070423  0.052817    0.882353  12.529412  0.048601    7.901408
# 299            0.080986  0.052817    0.882353  10.895141  0.047969    7.811620
# 286            0.088028  0.052817    0.882353  10.023529  0.047548    7.751761
# 200            0.080986  0.059859    0.850000  10.495652  0.054156    6.126761
# 227            0.073944  0.056338    0.842105  11.388471  0.051391    5.865023

# %%
#Substitute items Irish Basket
substitutes = association_rules(frq_items, metric="lift", min_threshold=0.0)
substitutes.sort_values(by='lift', ascending=True, inplace=True)
substitutes.head(10)
# Out:
#                            antecedents                         consequents  \
# 2                           (carriage)          (regency cakestand 3 tier)
# 3           (regency cakestand 3 tier)                          (carriage)
# 4                           (carriage)                (vintage snap cards)
# 5                 (vintage snap cards)                          (carriage)
# 50          (regency cakestand 3 tier)        (set of 3 regency cake tins)
# 51        (set of 3 regency cake tins)          (regency cakestand 3 tier)
# 49          (regency cakestand 3 tier)  (roses regency teacup and saucer )
# 48  (roses regency teacup and saucer )          (regency cakestand 3 tier)
# 8           (regency cakestand 3 tier)   (green regency teacup and saucer)
# 9    (green regency teacup and saucer)          (regency cakestand 3 tier)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 2             0.373239            0.246479  0.059859    0.160377  0.650674
# 3             0.246479            0.373239  0.059859    0.242857  0.650674
# 4             0.373239            0.154930  0.052817    0.141509  0.913379
# 5             0.154930            0.373239  0.052817    0.340909  0.913379
# 50            0.246479            0.123239  0.070423    0.285714  2.318367
# 51            0.123239            0.246479  0.070423    0.571429  2.318367
# 49            0.246479            0.169014  0.112676    0.457143  2.704762
# 48            0.169014            0.246479  0.112676    0.666667  2.704762
# 8             0.246479            0.126761  0.088028    0.357143  2.817460
# 9             0.126761            0.246479  0.088028    0.694444  2.817460
#
#     leverage  conviction
# 2  -0.032136    0.897452
# 3  -0.032136    0.827797
# 4  -0.005009    0.984368
# 5  -0.005009    0.950947
# 50  0.040047    1.227465
# 51  0.040047    1.758216
# 49  0.071018    1.530764
# 48  0.071018    2.260563
# 8   0.056784    1.358372
# 9   0.056784    2.466069

# %% [markdown]
# - If the basket is "full", suggest something useful for that specific customer
# - If the basket is "full" but the customer is unknown (guest) suggest a cold start product.

# %% [markdown]
# # Collaborative Filtering

# %%
df = pd.read_csv('cleaned_data2.csv', dtype={'StockCode': str}, parse_dates=['InvoiceDate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516528 entries, 0 to 516527
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    516528 non-null  object
#  1   StockCode    516528 non-null  object
#  2   Quantity     516528 non-null  int64
#  3   InvoiceDate  516528 non-null  datetime64[ns]
#  4   UnitPrice    516528 non-null  float64
#  5   CustomerID   392980 non-null  float64
#  6   Country      516528 non-null  object
#  7   TotalValue   516528 non-null  float64
#  8   Description  516528 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 35.5+ MB

# %%
#Dropping data without customer id, and quantity less than 0 
df_cust = df.dropna()
df_cust = df_cust[df_cust["Quantity"]>0]

#arranging data by customer id and stock code and quantity 
dfu=pd.DataFrame(df_cust.groupby(["CustomerID","StockCode"],as_index=False)["Quantity"].sum())
dfu.head()
# Out:
#    CustomerID StockCode  Quantity
# 0     12346.0     23166     74215
# 1     12347.0     16008        24
# 2     12347.0     17021        36
# 3     12347.0     20665         6
# 4     12347.0     20719        40

# %% [markdown]
# ### Assign autoincrementing ids starting from 0 to both users and items

# %%
ALL_USERS = dfu['CustomerID'].unique().tolist()
ALL_ITEMS = dfu['StockCode'].unique().tolist()

user_ids = dict(list(enumerate(ALL_USERS)))
item_ids = dict(list(enumerate(ALL_ITEMS)))

user_map = {u: uidx for uidx, u in user_ids.items()}
item_map = {i: iidx for iidx, i in item_ids.items()}

dfu['user_id'] = dfu['CustomerID'].map(user_map)
dfu['item_id'] = dfu['StockCode'].map(item_map)

dfu
# Out:
#         CustomerID StockCode  Quantity  user_id  item_id
# 0          12346.0     23166     74215        0        0
# 1          12347.0     16008        24        1        1
# 2          12347.0     17021        36        1        2
# 3          12347.0     20665         6        1        3
# 4          12347.0     20719        40        1        4
# ...            ...       ...       ...      ...      ...
# 256228     18287.0     84920         4     4328     1952
# 256229     18287.0    85039a        96     4328     1954
# 256230     18287.0    85039b       120     4328     2391
# 256231     18287.0    85040a        48     4328      302
# 256232     18287.0     85173        48     4328     1745
#
# [256233 rows x 5 columns]

# %%
#creating the sparce matrix needed for ALS algorithm 
row = dfu['user_id'].values
col = dfu['item_id'].values
data = dfu['Quantity'].values
coo_train = coo_matrix((data, (row, col)), shape=(len(ALL_USERS), len(ALL_ITEMS)))
coo_train
# Out:
# <4329x2487 sparse matrix of type '<class 'numpy.int64'>'
# 	with 256233 stored elements in COOrdinate format>

# %% [markdown]
# ### Check that model works ok with data

# %%
# %%time
model = implicit.als.AlternatingLeastSquares(factors=10, iterations=2)
model.fit(coo_train)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Wall time: 456 ms

# %% [markdown]
# ### Validation

# %%
#functions required for validation
def to_user_item_coo(df):
    """ Turn a dataframe with transactions into a COO sparse items x users matrix"""
    row = df['user_id'].values
    col = df['item_id'].values
    data = df['Quantity'].values
    coo = coo_matrix((data, (row, col)), shape=(len(ALL_USERS), len(ALL_ITEMS)))
    return coo


def split_data(df, validation_days=60):
    """ Split a pandas dataframe into training and validation data, using <<validation_days>>
    """
#    validation_cut = df['InvoiceDate'].max() - pd.Timedelta(validation_days)
    validation_cut = '2011-10-09 12:50:00'

    df_train = df[df['InvoiceDate'] < validation_cut]
    df_val = df[df['InvoiceDate'] >= validation_cut]
    return df_train, df_val

def get_val_matrices(df_train, df_val):
    """ Split into training and validation and create various matrices
        
        Returns a dictionary with the following keys:
            coo_train: training data in COO sparse format and as (users x items)
            csr_train: training data in CSR sparse format and as (users x items)
            csr_val:  validation data in CSR sparse format and as (users x items)
    
    """
#    df_train, df_val = split_data(df, validation_days=validation_days)
    coo_train = to_user_item_coo(df_train)
    coo_val = to_user_item_coo(df_val)

    csr_train = coo_train.tocsr()
    csr_val = coo_val.tocsr()
    
    return {'coo_train': coo_train,
            'csr_train': csr_train,
            'csr_val': csr_val
          }


def validate(matrices, factors=200, iterations=20, regularization=0.01, show_progress=True):
    """ Train an ALS model with <<factors>> (embeddings dimension) 
    for <<iterations>> over matrices and validate with MAP@5
    """
    coo_train, csr_train, csr_val = matrices['coo_train'], matrices['csr_train'], matrices['csr_val']
    
    model = implicit.als.AlternatingLeastSquares(factors=factors, 
                                                 iterations=iterations, 
                                                 regularization=regularization, 
                                                 random_state=42)
    model.fit(matrices['coo_train'], show_progress=show_progress)
    
    # The MAPK by implicit doesn't allow to calculate allowing repeated items, which is the case.
    # TODO: change MAP@5 to a library that allows repeated items in prediction
    map5 = mean_average_precision_at_k(model, csr_train, csr_val, K=5, show_progress=show_progress)
    print(f"Factors: {factors:>3} - Iterations: {iterations:>2} - Regularization: {regularization:4.3f} ==> MAP@5: {map5:6.5f}")
    return map5

# %%
# train-test split based on timestamp: '2011-10-09 12:50:00'
df_train, df_val= split_data(df_cust)

# %%
df_val['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
#adding necessary labels and creating the sparse matrices: 
df_train = pd.DataFrame(df_train.groupby(["CustomerID","StockCode"],as_index=False)["Quantity"].sum())
df_train['user_id'] = df_train['CustomerID'].map(user_map)
df_train['item_id'] = df_train['StockCode'].map(item_map)

df_val = pd.DataFrame(df_val.groupby(["CustomerID","StockCode"],as_index=False)["Quantity"].sum())
df_val['user_id'] = df_val['CustomerID'].map(user_map)
df_val['item_id'] = df_val['StockCode'].map(item_map)

# %%
matrices = get_val_matrices(df_train, df_val)

# %%
#MAP with preset parameters 
#score is higher because the original model was build with validation data
mean_average_precision_at_k(model, matrices['csr_train'], matrices['csr_val'], K=5, show_progress=False)
# Out:
# 0.09201475048249211

# %%
#finding ideal parameters:
# %%time
best_map5 = 0
for factors in [40, 50, 60, 100, 200, 500, 1000]:
    for iterations in [3, 12, 14, 15, 20]:
        for regularization in [0.01]:
            map5 = validate(matrices, factors, iterations, regularization, show_progress=False)
            if map5 > best_map5:
                best_map5 = map5
                best_params = {'factors': factors, 'iterations': iterations, 'regularization': regularization}
                print(f"Best MAP@5 found. Updating: {best_params}")
# Out:
# Factors:  40 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02632
# Best MAP@5 found. Updating: {'factors': 40, 'iterations': 3, 'regularization': 0.01}
# Factors:  40 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.03061
# Best MAP@5 found. Updating: {'factors': 40, 'iterations': 12, 'regularization': 0.01}
# Factors:  40 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.03073
# Best MAP@5 found. Updating: {'factors': 40, 'iterations': 14, 'regularization': 0.01}
# Factors:  40 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.03058
# Factors:  40 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.03108
# Best MAP@5 found. Updating: {'factors': 40, 'iterations': 20, 'regularization': 0.01}
# Factors:  50 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02718
# Factors:  50 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.03214
# Best MAP@5 found. Updating: {'factors': 50, 'iterations': 12, 'regularization': 0.01}
# Factors:  50 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.03242
# Best MAP@5 found. Updating: {'factors': 50, 'iterations': 14, 'regularization': 0.01}
# Factors:  50 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.03222
# Factors:  50 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.03223
# Factors:  60 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.03058
# Factors:  60 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.03417
# Best MAP@5 found. Updating: {'factors': 60, 'iterations': 12, 'regularization': 0.01}
# Factors:  60 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.03444
# Best MAP@5 found. Updating: {'factors': 60, 'iterations': 14, 'regularization': 0.01}
# Factors:  60 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.03428
# Factors:  60 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.03479
# Best MAP@5 found. Updating: {'factors': 60, 'iterations': 20, 'regularization': 0.01}
# Factors: 100 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.03026
# Factors: 100 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.03638
# Best MAP@5 found. Updating: {'factors': 100, 'iterations': 12, 'regularization': 0.01}
# Factors: 100 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.03684
# Best MAP@5 found. Updating: {'factors': 100, 'iterations': 14, 'regularization': 0.01}
# Factors: 100 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.03673
# Factors: 100 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.03658
# Factors: 200 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.03214
# Factors: 200 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.03712
# Best MAP@5 found. Updating: {'factors': 200, 'iterations': 12, 'regularization': 0.01}
# Factors: 200 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.03719
# Best MAP@5 found. Updating: {'factors': 200, 'iterations': 14, 'regularization': 0.01}
# Factors: 200 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.03684
# Factors: 200 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.03649
# Factors: 500 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.03121
# Factors: 500 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.03186
# Factors: 500 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.03132
# Factors: 500 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.03135
# Factors: 500 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.03026
# Factors: 1000 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02718
# Factors: 1000 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02584
# Factors: 1000 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02536
# Factors: 1000 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02506
# Factors: 1000 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02408
# Wall time: 5min 34s

# %%
best_params
# Out:
# {'factors': 200, 'iterations': 14, 'regularization': 0.01}

# %%
#built model with best parameters:
model = implicit.als.AlternatingLeastSquares(**best_params,
                                            random_state=42)
model.fit(matrices['coo_train'], show_progress=True)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]

# %%
#presicion with best parameters
mean_average_precision_at_k(model, matrices['csr_train'], matrices['csr_val'], K=5, show_progress=False)
# Out:
# 0.037187413840639685

# %% [markdown]
# ## Testing a smaller timeline

# %%
#based on some of the research we did, we also tried building the model over a smaller timeline
# this could be the case if tends change significantly over the year
batch_date_start = '2011-06-01 12:50:00'
batch_date_end = '2011-07-01 12:50:00'
df_cust_small = df_cust[(df_cust['InvoiceDate'] >= batch_date_start)&(df_cust['InvoiceDate'] < batch_date_end)]
df_cust_small
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 196850    555234     48185         3 2011-06-01 12:54:00       7.95
# 196851    555234     48194         6 2011-06-01 12:54:00       7.95
# 196852    555234     48188         2 2011-06-01 12:54:00       7.95
# 196853    555234     22189        10 2011-06-01 12:54:00       3.95
# 196854    555234     22178        24 2011-06-01 12:54:00       1.25
# ...          ...       ...       ...                 ...        ...
# 232256    558703     23146         4 2011-07-01 12:47:00       3.29
# 232257    558703     22726         4 2011-07-01 12:47:00       3.75
# 232258    558703     22729         4 2011-07-01 12:47:00       3.75
# 232259    558703     84879        16 2011-07-01 12:47:00       1.69
# 232260    558703     22197        12 2011-07-01 12:47:00       0.85
#
#         CustomerID         Country  TotalValue  \
# 196850     14515.0  United Kingdom       23.85
# 196851     14515.0  United Kingdom       47.70
# 196852     14515.0  United Kingdom       15.90
# 196853     14515.0  United Kingdom       39.50
# 196854     14515.0  United Kingdom       30.00
# ...            ...             ...         ...
# 232256     13730.0  United Kingdom       13.16
# 232257     13730.0  United Kingdom       15.00
# 232258     13730.0  United Kingdom       15.00
# 232259     13730.0  United Kingdom       27.04
# 232260     13730.0  United Kingdom       10.20
#
#                             Description
# 196850               doormat fairy cake
# 196851                   doormat hearts
# 196852          doormat welcome puppies
# 196853          cream heart card holder
# 196854  victorian glass hanging t-light
# ...                                 ...
# 232256   triple hook antique ivory rose
# 232257       alarm clock bakelike green
# 232258      alarm clock bakelike orange
# 232259    assorted colour bird ornament
# 232260                   popcorn holder
#
# [26470 rows x 9 columns]

# %%
validation_cut = '2011-06-22 12:50:00'

df_train = df_cust_small[df_cust_small['InvoiceDate'] < validation_cut]
df_val = df_cust_small[df_cust_small['InvoiceDate'] >= validation_cut]

# %%
df_train = pd.DataFrame(df_train.groupby(["CustomerID","StockCode"],as_index=False)["Quantity"].sum())
df_train['user_id'] = df_train['CustomerID'].map(user_map)
df_train['item_id'] = df_train['StockCode'].map(item_map)

df_val = pd.DataFrame(df_val.groupby(["CustomerID","StockCode"],as_index=False)["Quantity"].sum())
df_val['user_id'] = df_val['CustomerID'].map(user_map)
df_val['item_id'] = df_val['StockCode'].map(item_map)

# %%
matrices = get_val_matrices(df_train, df_val)

# %%
df_val
# Out:
#       CustomerID StockCode  Quantity  user_id  item_id
# 0        12379.0     20665         6       28        3
# 1        12379.0     20674         8       28      578
# 2        12379.0     20676         8       28      250
# 3        12379.0     20750        12       28      254
# 4        12379.0     21080        12       28      255
# ...          ...       ...       ...      ...      ...
# 6934     18283.0    84997b         1     4327       95
# 6935     18283.0    84997d         1     4327       97
# 6936     18283.0    85099b         3     4327      575
# 6937     18283.0    85099f         2     4327      577
# 6938     18283.0    85123a         1     4327      861
#
# [6939 rows x 5 columns]

# %%
# %%time
best_map5 = 0
for factors in [40, 50, 60, 100, 200, 500, 1000]:
    for iterations in [3, 12, 14, 15, 20]:
        for regularization in [0.01]:
            map5 = validate(matrices, factors, iterations, regularization, show_progress=False)
            if map5 > best_map5:
                best_map5 = map5
                best_params = {'factors': factors, 'iterations': iterations, 'regularization': regularization}
                print(f"Best MAP@5 found. Updating: {best_params}")
# Out:
# Factors:  40 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02278
# Best MAP@5 found. Updating: {'factors': 40, 'iterations': 3, 'regularization': 0.01}
# Factors:  40 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02396
# Best MAP@5 found. Updating: {'factors': 40, 'iterations': 12, 'regularization': 0.01}
# Factors:  40 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02341
# Factors:  40 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02321
# Factors:  40 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02301
# Factors:  50 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02953
# Best MAP@5 found. Updating: {'factors': 50, 'iterations': 3, 'regularization': 0.01}
# Factors:  50 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02769
# Factors:  50 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02797
# Factors:  50 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02835
# Factors:  50 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02674
# Factors:  60 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02696
# Factors:  60 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02611
# Factors:  60 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02609
# Factors:  60 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02547
# Factors:  60 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02607
# Factors: 100 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02252
# Factors: 100 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02445
# Factors: 100 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02513
# Factors: 100 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02460
# Factors: 100 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02432
# Factors: 200 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02556
# Factors: 200 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02288
# Factors: 200 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02240
# Factors: 200 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02131
# Factors: 200 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02090
# Factors: 500 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02546
# Factors: 500 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02719
# Factors: 500 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02665
# Factors: 500 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02607
# Factors: 500 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02464
# Factors: 1000 - Iterations:  3 - Regularization: 0.010 ==> MAP@5: 0.02481
# Factors: 1000 - Iterations: 12 - Regularization: 0.010 ==> MAP@5: 0.02710
# Factors: 1000 - Iterations: 14 - Regularization: 0.010 ==> MAP@5: 0.02614
# Factors: 1000 - Iterations: 15 - Regularization: 0.010 ==> MAP@5: 0.02637
# Factors: 1000 - Iterations: 20 - Regularization: 0.010 ==> MAP@5: 0.02594
# Wall time: 1min 44s

# %%
best_params
# Out:
# {'factors': 50, 'iterations': 3, 'regularization': 0.01}

# %%
#running the model on the new parameters and data partition
model = implicit.als.AlternatingLeastSquares(**best_params,
                                            random_state=42)
model.fit(matrices['coo_train'], show_progress=True)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#results are lower than the full dataset, so its better to train the model on all data
mean_average_precision_at_k(model, matrices['csr_train'], matrices['csr_val'], K=5, show_progress=False)
# Out:
# 0.029527600849256905

# %% [markdown]
# # Training over the full dataset

# %%
# now we can run the model on the full dataset
coo_train = to_user_item_coo(dfu)
csr_train = coo_train.tocsr()

# %%
#parameters from our best training
best_params = {'factors': 200, 'iterations': 14, 'regularization': 0.01}

# %%
model = implicit.als.AlternatingLeastSquares(**best_params,
                                            random_state=42)
model.fit(coo_train, show_progress=True)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]

# %% [markdown]
# # Getting recommendations

# %%
#creating some reference tables
customer_reference = dfu[["CustomerID",'user_id']].drop_duplicates()
item_reference = dfu[["StockCode",'item_id']].drop_duplicates()
item_reference=pd.merge(item_reference,df_cust[["StockCode","Description"]], on="StockCode", how="left").drop_duplicates()

# %%
#getting user recommendations
#customer_id = 14789
user_id = 1790

# Use the implicit recommender.
recommended = model.recommend(user_id, csr_train[user_id], N=5)

recomendations_list = recommended[0].tolist()
items = []
description = []
score = []


# Get artist names from ids
for item in recomendations_list:
    items.append(dfu["StockCode"][dfu.item_id == item].unique().tolist())

items = [item for sublist in items for item in sublist]
recommendations = pd.DataFrame({'items': items, 'score': recommended[1]})
print(recommendations)
# Out:
#    items     score
# 0  20972  0.581438
# 1  22644  0.503945
# 2  22898  0.499361
# 3  22617  0.499310
# 4  22646  0.498556

# %%
#top 5 recommendations for selected user: 
item_reference[item_reference["StockCode"].isin(items)]
# Out:
#        StockCode  item_id                         Description
# 60510      22617      211          baking set spaceboy design
# 63142      22646      218  ceramic strawberry cake money bank
# 152491     22898      618       childrens apron apples design
# 182508     20972      756  pink cream felt craft trinket box
# 215122     22644      918      ceramic cherry cake money bank

# %%
#items purchased by this user
cust_id_lookup=customer_reference["CustomerID"][customer_reference["user_id"]==user_id].tolist()
df_cust[df_cust["CustomerID"]==cust_id_lookup[0]]
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 435145    575737     21108        36 2011-11-11 08:59:00       0.79
# 435146    575737     22367        16 2011-11-11 08:59:00       1.95
# 435147    575737    47591d        16 2011-11-11 08:59:00       1.95
# 435148    575737     20971        24 2011-11-11 08:59:00       1.25
# 435149    575737     22645        12 2011-11-11 08:59:00       1.45
# 435150    575737     22138        12 2011-11-11 08:59:00       4.95
#
#         CustomerID         Country  TotalValue  \
# 435145     14789.0  United Kingdom       28.44
# 435146     14789.0  United Kingdom       31.20
# 435147     14789.0  United Kingdom       31.20
# 435148     14789.0  United Kingdom       30.00
# 435149     14789.0  United Kingdom       17.40
# 435150     14789.0  United Kingdom       59.40
#
#                                 Description
# 435145   fairy cake flannel assorted colour
# 435146      childrens apron spaceboy design
# 435147      pink fairy cake childrens apron
# 435148     pink blue felt craft trinket box
# 435149  ceramic heart fairy cake money bank
# 435150        baking set 9 piece retrospot

# %%
#getting user recommendations
#customer_id = 13120
user_id = 586

# Use the implicit recommender.
recommended = model.recommend(user_id, csr_train[user_id], N=5)

recomendations_list = recommended[0].tolist()
items = []
description = []
score = []


# Get artist names from ids
for item in recomendations_list:
    items.append(dfu["StockCode"][dfu.item_id == item].unique().tolist())

items = [item for sublist in items for item in sublist]
recommendations = pd.DataFrame({'items': items, 'score': recommended[1]})
print(recommendations)
# Out:
#     items     score
# 0  82494l  0.638831
# 1   82483  0.251663
# 2   82486  0.224138
# 3   82484  0.194639
# 4   22766  0.190953

# %%
#top 5 recommendations for selected user: 
item_reference[item_reference["StockCode"].isin(items)]
# Out:
#        StockCode  item_id                         Description
# 139133     82484      569   wood black board ant white finish
# 197158     22766      843                 photo frame cornice
# 324020    82494l     1649         wooden frame antique white
# 328763     82483     1698  wood 2 drawer cabinet white finish
# 329284     82486     1699   wood s/3 cabinet ant white finish

# %%
#items purchased by this user
cust_id_lookup=customer_reference["CustomerID"][customer_reference["user_id"]==user_id].tolist()
df_cust[df_cust["CustomerID"]==cust_id_lookup[0]]
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 147137    550198     82482        12 2011-04-15 10:19:00       2.55
#
#         CustomerID         Country  TotalValue  \
# 147137     13120.0  United Kingdom        30.6
#
#                               Description
# 147137  wooden picture frame white finish

# %%
#getting user recommendations
#customerID = 12853
user_id = 400

# Use the implicit recommender.
recommended = model.recommend(user_id, csr_train[user_id], N=5)

recomendations_list = recommended[0].tolist()
items = []
description = []
score = []


# Get artist names from ids
for item in recomendations_list:
    items.append(dfu["StockCode"][dfu.item_id == item].unique().tolist())

items = [item for sublist in items for item in sublist]
recommendations = pd.DataFrame({'items': items, 'score': recommended[1]})
print(recommendations)
# Out:
#    items     score
# 0  22854  0.765817
# 1  23208  0.729869
# 2  22726  0.720887
# 3  48194  0.706198
# 4  22173  0.662107

# %%
#top 5 recommendations for selected user: 
item_reference[item_reference["StockCode"].isin(items)]
# Out:
#        StockCode  item_id                         Description
# 12214      22726       45          alarm clock bakelike green
# 50089      48194      179                      doormat hearts
# 132129     23208      533       lunch bag vintage leaf design
# 319563     22173     1618  metal 4 hook hanger french chateau
# 358758     22854     2012         cream sweetheart egg holder

# %%
#items purchased by this user
pd.set_option('display.max_rows', None)
cust_id_lookup=customer_reference["CustomerID"][customer_reference["user_id"]==user_id].tolist()
df_cust[df_cust["CustomerID"]==cust_id_lookup[0]]
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 69233     542431     22988        12 2011-01-28 10:28:00       1.25
# 69234     542431     22652        10 2011-01-28 10:28:00       1.65
# 69235     542431     84380        12 2011-01-28 10:28:00       1.25
# 69236     542431     84378        12 2011-01-28 10:28:00       1.25
# 69237     542431     22966        12 2011-01-28 10:28:00       1.25
# 69238     542431     22666         6 2011-01-28 10:28:00       2.95
# 69239     542431     22170         4 2011-01-28 10:28:00       6.75
# 69240     542431     22169         4 2011-01-28 10:28:00       8.50
# 69241     542431     22171         2 2011-01-28 10:28:00       8.50
# 69242     542431     22795         4 2011-01-28 10:28:00       6.75
# 69243     542431     85066         2 2011-01-28 10:28:00      12.75
# 69244     542431     22148        12 2011-01-28 10:28:00       1.95
# 69245     542431     22241        12 2011-01-28 10:28:00       1.25
# 69246     542431     22502         4 2011-01-28 10:28:00       5.95
# 69247     542431     22926         4 2011-01-28 10:28:00       5.95
# 69248     542431     22933         6 2011-01-28 10:28:00       2.95
# 69249     542431     22934         6 2011-01-28 10:28:00       2.95
# 69250     542431     22457         6 2011-01-28 10:28:00       2.95
# 69251     542431     48138         4 2011-01-28 10:28:00       7.95
# 69252     542431     20685         4 2011-01-28 10:28:00       7.95
# 146088    550124     22139         6 2011-04-14 12:41:00       4.95
# 146089    550124     22904         6 2011-04-14 12:41:00       2.95
# 146090    550124     22423         4 2011-04-14 12:41:00      12.75
# 146091    550124     84988        12 2011-04-14 12:41:00       1.45
# 146092    550124     21212        24 2011-04-14 12:41:00       0.55
# 146093    550124     22178        12 2011-04-14 12:41:00       1.25
# 146094    550124     22457         6 2011-04-14 12:41:00       2.95
# 146095    550124     22927         2 2011-04-14 12:41:00       5.95
# 146096    550124     22926         2 2011-04-14 12:41:00       5.95
# 146097    550124     22925         2 2011-04-14 12:41:00       5.95
# 146098    550124     22171         2 2011-04-14 12:41:00       8.50
# 146099    550124     22170         4 2011-04-14 12:41:00       6.75
# 146100    550124     22169         2 2011-04-14 12:41:00       8.50
# 146101    550124     21390        24 2011-04-14 12:41:00       1.25
# 146102    550124     22794         2 2011-04-14 12:41:00       7.95
# 146103    550124     22502         4 2011-04-14 12:41:00       5.95
# 146127    550126     23199        10 2011-04-14 12:43:00       1.95
# 146128    550126     23077        40 2011-04-14 12:43:00       1.25
# 146129    550126     22993        12 2011-04-14 12:43:00       1.25
# 146130    550126     22727         4 2011-04-14 12:43:00       3.75
# 146131    550126     22729         4 2011-04-14 12:43:00       3.75
# 146132    550126     22728         4 2011-04-14 12:43:00       3.75
# 265544    561595     22086        24 2011-07-28 11:22:00       2.95
# 265545    561595     84832        12 2011-07-28 11:22:00       0.85
# 265546    561595     22141        12 2011-07-28 11:22:00       2.10
# 265547    561595     22144        12 2011-07-28 11:22:00       2.10
# 265548    561595     23267        12 2011-07-28 11:22:00       1.25
# 265549    561595     23206        10 2011-07-28 11:22:00       1.65
# 265550    561595     20725        10 2011-07-28 11:22:00       1.65
# 265551    561595     23209        10 2011-07-28 11:22:00       1.65
# 265552    561595     23202        10 2011-07-28 11:22:00       2.08
# 265553    561595     23203        10 2011-07-28 11:22:00       2.08
# 265554    561595    85099b        10 2011-07-28 11:22:00       2.08
# 265555    561595     22741        96 2011-07-28 11:22:00       0.85
# 265556    561595     22740        96 2011-07-28 11:22:00       0.85
# 265557    561595     23297        12 2011-07-28 11:22:00       1.65
# 265558    561595     22993        12 2011-07-28 11:22:00       1.25
# 265559    561595     23338         6 2011-07-28 11:22:00       2.08
# 265560    561595     23336         6 2011-07-28 11:22:00       2.08
# 265561    561595     23337         6 2011-07-28 11:22:00       2.08
# 265562    561595     23339         6 2011-07-28 11:22:00       2.08
# 265563    561595     23335         6 2011-07-28 11:22:00       2.08
# 265564    561595     22725         8 2011-07-28 11:22:00       3.75
# 265565    561595     23153         8 2011-07-28 11:22:00       3.75
# 265566    561595     22169         4 2011-07-28 11:22:00       8.50
# 265567    561595     22170        12 2011-07-28 11:22:00       5.95
# 265568    561595     22171         4 2011-07-28 11:22:00       8.50
# 265569    561595     85066         6 2011-07-28 11:22:00      12.75
# 265570    561595     22112         8 2011-07-28 11:22:00       4.95
# 265571    561595     22690         4 2011-07-28 11:22:00       7.95
# 265572    561595     48188         4 2011-07-28 11:22:00       7.95
# 265582    561597     23175         6 2011-07-28 11:26:00       3.25
# 265583    561597     23173         2 2011-07-28 11:26:00       9.95
# 265584    561597     23245         4 2011-07-28 11:26:00       4.95
# 265585    561597     21210        12 2011-07-28 11:26:00       1.45
# 265586    561597     23110         4 2011-07-28 11:26:00       5.75
# 265587    561597     22795         4 2011-07-28 11:26:00       6.75
# 265589    561599     23284         6 2011-07-28 11:29:00       7.95
#
#         CustomerID         Country  TotalValue  \
# 69233      12853.0  United Kingdom       15.00
# 69234      12853.0  United Kingdom       16.50
# 69235      12853.0  United Kingdom       15.00
# 69236      12853.0  United Kingdom       15.00
# 69237      12853.0  United Kingdom       15.00
# 69238      12853.0  United Kingdom       17.70
# 69239      12853.0  United Kingdom       27.00
# 69240      12853.0  United Kingdom       34.00
# 69241      12853.0  United Kingdom       17.00
# 69242      12853.0  United Kingdom       27.00
# 69243      12853.0  United Kingdom       25.50
# 69244      12853.0  United Kingdom       23.40
# 69245      12853.0  United Kingdom       15.00
# 69246      12853.0  United Kingdom       23.80
# 69247      12853.0  United Kingdom       23.80
# 69248      12853.0  United Kingdom       17.70
# 69249      12853.0  United Kingdom       17.70
# 69250      12853.0  United Kingdom       17.70
# 69251      12853.0  United Kingdom       31.80
# 69252      12853.0  United Kingdom       31.80
# 146088     12853.0  United Kingdom       29.70
# 146089     12853.0  United Kingdom       17.70
# 146090     12853.0  United Kingdom       51.00
# 146091     12853.0  United Kingdom       17.40
# 146092     12853.0  United Kingdom       13.20
# 146093     12853.0  United Kingdom       15.00
# 146094     12853.0  United Kingdom       17.70
# 146095     12853.0  United Kingdom       11.90
# 146096     12853.0  United Kingdom       11.90
# 146097     12853.0  United Kingdom       11.90
# 146098     12853.0  United Kingdom       17.00
# 146099     12853.0  United Kingdom       27.00
# 146100     12853.0  United Kingdom       17.00
# 146101     12853.0  United Kingdom       30.00
# 146102     12853.0  United Kingdom       15.90
# 146103     12853.0  United Kingdom       23.80
# 146127     12853.0  United Kingdom       19.50
# 146128     12853.0  United Kingdom       50.00
# 146129     12853.0  United Kingdom       15.00
# 146130     12853.0  United Kingdom       15.00
# 146131     12853.0  United Kingdom       15.00
# 146132     12853.0  United Kingdom       15.00
# 265544     12853.0  United Kingdom       70.80
# 265545     12853.0  United Kingdom       10.20
# 265546     12853.0  United Kingdom       25.20
# 265547     12853.0  United Kingdom       25.20
# 265548     12853.0  United Kingdom       15.00
# 265549     12853.0  United Kingdom       16.50
# 265550     12853.0  United Kingdom       16.50
# 265551     12853.0  United Kingdom       16.50
# 265552     12853.0  United Kingdom       20.80
# 265553     12853.0  United Kingdom       20.80
# 265554     12853.0  United Kingdom       20.80
# 265555     12853.0  United Kingdom       81.60
# 265556     12853.0  United Kingdom       81.60
# 265557     12853.0  United Kingdom       19.80
# 265558     12853.0  United Kingdom       15.00
# 265559     12853.0  United Kingdom       12.48
# 265560     12853.0  United Kingdom       12.48
# 265561     12853.0  United Kingdom       12.48
# 265562     12853.0  United Kingdom       12.48
# 265563     12853.0  United Kingdom       12.48
# 265564     12853.0  United Kingdom       30.00
# 265565     12853.0  United Kingdom       30.00
# 265566     12853.0  United Kingdom       34.00
# 265567     12853.0  United Kingdom       71.40
# 265568     12853.0  United Kingdom       34.00
# 265569     12853.0  United Kingdom       76.50
# 265570     12853.0  United Kingdom       39.60
# 265571     12853.0  United Kingdom       31.80
# 265572     12853.0  United Kingdom       31.80
# 265582     12853.0  United Kingdom       19.50
# 265583     12853.0  United Kingdom       19.90
# 265584     12853.0  United Kingdom       19.80
# 265585     12853.0  United Kingdom       17.40
# 265586     12853.0  United Kingdom       23.00
# 265587     12853.0  United Kingdom       27.00
# 265589     12853.0  United Kingdom       47.70
#
#                                 Description
# 69233                     soldiers egg cup
# 69234                     travel sewing kit
# 69235     set of 3 butterfly cookie cutters
# 69236         set of 3 heart cookie cutters
# 69237         gingerbread man cookie cutter
# 69238       recipe box pantry yellow design
# 69239    picture frame wood triple portrait
# 69240      family album white picture frame
# 69241      3 hook photo shelf antique white
# 69242          sweetheart recipe book stand
# 69243           cream sweetheart mini chest
# 69244                easter craft 4 chicks
# 69245           garland wooden happy easter
# 69246            picnic basket wicker small
# 69247        ivory giant garden thermometer
# 69248     baking mould easter egg milk choc
# 69249    baking mould easter egg white choc
# 69250       natural slate heart chalkboard
# 69251                    doormat union flag
# 69252                 doormat red retrospot
# 146088     retrospot tea set ceramic 11 pc
# 146089            calendar paper cut design
# 146090             regency cakestand 3 tier
# 146091   set of 72 pink heart paper doilies
# 146092      pack of 72 retrospot cake cases
# 146093      victorian glass hanging t-light
# 146094      natural slate heart chalkboard
# 146095       green giant garden thermometer
# 146096       ivory giant garden thermometer
# 146097        blue giant garden thermometer
# 146098     3 hook photo shelf antique white
# 146099   picture frame wood triple portrait
# 146100     family album white picture frame
# 146101        filigris heart with butterfly
# 146102        sweetheart wire magazine rack
# 146103           picnic basket wicker small
# 146127                     jumbo bag apples
# 146128                  doughnut lip gloss
# 146129         set of 4 pantry jelly moulds
# 146130            alarm clock bakelike red
# 146131          alarm clock bakelike orange
# 146132            alarm clock bakelike pink
# 265544      paper chain kit 50's christmas
# 265545     zinc willie winkie  candle stick
# 265546       christmas craft tree top angel
# 265547       christmas craft little friends
# 265548        set of 4 santa place settings
# 265549               lunch bag apple design
# 265550              lunch bag red retrospot
# 265551             lunch bag vintage doily
# 265552               jumbo bag vintage leaf
# 265553             jumbo bag vintage doily
# 265554              jumbo bag red retrospot
# 265555                       funky diva pen
# 265556                         polkadot pen
# 265557  set 40 heart shape petit four cases
# 265558         set of 4 pantry jelly moulds
# 265559                  egg frying pan red
# 265560                 egg frying pan pink
# 265561                 egg frying pan mint
# 265562                 egg frying pan blue
# 265563                egg frying pan ivory
# 265564       alarm clock bakelike chocolate
# 265565     zinc sweetheart wire letter rack
# 265566     family album white picture frame
# 265567   picture frame wood triple portrait
# 265568     3 hook photo shelf antique white
# 265569          cream sweetheart mini chest
# 265570           chocolate hot water bottle
# 265571        doormat home sweet home blue
# 265572              doormat welcome puppies
# 265582               regency milk jug pink
# 265583                regency teapot roses
# 265584           set of 3 regency cake tins
# 265585   set of 72 retrospot paper  doilies
# 265586              parisienne key cabinet
# 265587         sweetheart recipe book stand
# 265589        doormat keep calm and come in
